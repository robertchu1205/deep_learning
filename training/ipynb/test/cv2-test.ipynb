# %%
import matplotlib.pyplot as plt
import cv2 
import os
import numpy as np
import shutil

img_path = '/data/aoi-wzs-p1-dip-fa-nvidia/5class_missed_label/None/180/MBK907W21001B20_LAMI_180_000_000.jpg'
gray = cv2.imread(img_path, 0)
print(gray.shape, gray[0,0:10])
plt.imshow(gray, 'gray')
# Out:
# (541, 535) [42 42 42 42 43 44 45 45 42 43]

# %%
brightTh,brightArea = cv2.threshold(gray,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU) # BINARY 0, OTSU 8
# brightTh,brightArea = cv2.threshold(gray,127,255,cv2.THRESH_BINARY)
# brightArea = cv2.adaptiveThreshold(gray,255,cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY,11,2)
plt.imshow(brightArea, 'gray')

# %%
brightArea = cv2.bitwise_not(brightArea)
H = cv2.Sobel(brightArea, cv2.CV_8U, 0, 2)
V = cv2.Sobel(brightArea, cv2.CV_8U, 2, 0)
# kernel2 = np.ones((3,3), np.uint8)
# brightArea = cv2.morphologyEx(brightArea, cv2.MORPH_OPEN, kernel2) #去掉邊緣連著的鬚鬚
plt.imshow(H, 'gray')
